# %%
import pandas as pd
import numpy as np
import gc
from sklearn.feature_selection import mutual_info_classif
from category_encoders import MEstimateEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import warnings


# 在全局范围内禁止输出 SettingWithCopyWarning 警告
warnings.filterwarnings('ignore')

# %%
def set_table_dtypes(df):
    for col in df.columns:
        if col in ["case_id", "WEEK_NUM", "num_group1", "num_group2"]:
            df[col] = df[col].astype('int32')  # 使用更小的整数类型
        elif col in ["date_decision"]:
            df[col] = pd.to_datetime(df[col])  # 转换为datetime类型
        elif col[-1] in ("P", "A"):
            df[col] = df[col].astype('float32')  # 使用更小的浮点数类型
        elif col[-1] in ("M",):
            df[col] = df[col].astype('category')  # 使用压缩编码的category类型
        elif df[col].dtype == bool:
            df[col] = df[col].astype('int32')  # 使用更小的整数类型
        elif col[-1] in ("D",):
            df[col] = pd.to_datetime(df[col])  # 转换为datetime类型
       
        # 将所有的float64类型转换为float32类型
        if df[col].dtype == 'float64':
            df[col] = df[col].astype('float32')
        # 将所有的int64类型转换为int32类型
        elif df[col].dtype == 'int64':
            df[col] = df[col].astype('int32')
        gc.collect()

def handle_dates(df):
    df = pd.merge(df, base[['case_id', 'date_decision']], on='case_id', how='left')
    df = pd.merge(df, person1[['case_id', 'birth_259']], on='case_id', how='left')
    
    for col in df.columns:
        if col in ['date_decision', 'birth_259']:
            df[col] = pd.to_datetime(df[col])
           
        if col.endswith("D"):
            # Calculate the difference in days for "date_decision" - col
            new_col_name_1 = col + '_date_diff'
            df[new_col_name_1] = (df["date_decision"] - df[col]).dt.days
            
            # Calculate the difference in days for col - "birth_259"
            new_col_name_2 = col + '_birth_diff'
            df[new_col_name_2] = (df[col] - df["birth_259"]).dt.days

    # Drop the original date columns and original columns ending with "D"
    cols_to_drop = [col for col in df.columns if col.endswith("D")]
    cols_to_drop += ['date_decision', 'birth_259']
    df = df.drop(columns=cols_to_drop)
    
    return df
#outliers
def outliers(df, q=0.0001):
    for col in df.columns:
         if df[col].dtype == 'float32' or df[col].dtype == 'float64':
            lower_bound = df[col].quantile(q)
            upper_bound = df[col].quantile(1 - q)
            df[col]=df[col].clip(lower_bound, upper_bound)
    return df

# %%
def transforms(df, df_name):
    # 记录要删除的原始列
    cols_to_drop = []
    print('coming...')
    for col in df.columns:
        grouped_series = df.groupby('case_id')[col]
        print('got it！')
        if col not in ["target", "case_id", "WEEK_NUM", 'num_group1', 'num_group2']:
            if col.endswith(("P", "A")):
                df[f"{col}_max"] = grouped_series.transform('max')
                df[f"{col}_median"] = grouped_series.transform('median')
                df[f"{col}_mean"] = grouped_series.transform('mean')
                df[f"{col}_first"] = grouped_series.transform('first')
                df[f"{col}_last"] = grouped_series.transform('last')
                cols_to_drop.append(col)  # 添加要删除的原始列
            elif col.endswith("D"):
                df[f"{col}_max"] = grouped_series.transform('max')
                df[f"{col}_mean"] = grouped_series.transform('mean')
                df[f"{col}_last"] = grouped_series.transform('last')
                cols_to_drop.append(col)  # 添加要删除的原始列
            elif col.endswith("M"):
                df[f"{col}_n"] = grouped_series.transform('nunique')
                df[f"{col}_last"] = grouped_series.transform('last')
                cols_to_drop.append(col)  # 添加要删除的原始列
            elif col.endswith(("T", "L")) and df[col].dtype != 'object' and df[col].dtype != 'category':
                df[f"{col}_max"] = grouped_series.transform('max')
                df[f"{col}_mean"] = grouped_series.transform('mean')
                df[f"{col}_first"] = grouped_series.transform('first')
                df[f"{col}_last"] = grouped_series.transform('last')
                cols_to_drop.append(col)
            elif col.endswith(("T", "L")) and (df[col].dtype == 'object' or df[col].dtype != 'category'):
                df[f"{col}_n"] = grouped_series.transform('nunique')
                df[f"{col}_first"] = grouped_series.transform('first')
                df[f"{col}_last"] = grouped_series.transform('last')
                cols_to_drop.append(col)
        elif 'num_group' in col:
            grouped_series = df.groupby('case_id')[col]
            df[f"{col}_{df_name}_max"] = grouped_series.transform('max')
            df[f"{col}_{df_name}_count"] = grouped_series.transform('count')
            
            cols_to_drop.append(col)  # 添加要删除的原始列

    # 删除要删除的原始列
    df=df.drop(columns=cols_to_drop)
    gc.collect()
    return df

# %%
def missing(df):
    for col in df.columns:
        if col not in ["target", "case_id", "WEEK_NUM"]:
            isnull = df[col].isnull().mean()
            if isnull >= 0.7:
                df=df.drop(col,axis=1)
    return df

def sparse(df):
    for col in df.columns:
        if (col not in ["target", "case_id", "WEEK_NUM"]) and (df[col].dtype == 'object' or df[col].dtype == 'category'):
            freq = df[col].nunique()
            if (freq == 1) or (freq >= 500):
                df = df.drop(col, axis=1)
            else:  # 处理低频值
                infrequent_mask = df[col].isin(df[col].value_counts()[df[col].value_counts() < 0.001 * len(df)].index)
                df.loc[infrequent_mask, col] = np.nan
                
                # 计算最常见值的比例
                most_common_value_ratio = df[col].value_counts(normalize=True).max()
                
                # 如果最常见值的比例超过98%，则删除该列
                if most_common_value_ratio >= 0.98:
                    df = df.drop(col, axis=1)
    return df

# %%
def read_file(paths, name):
    if isinstance(paths, str):# If only one file path is provided
        data = pd.read_parquet(paths)
        set_table_dtypes(data)
        data=sparse(data)
        data=outliers(data)
        data = handle_dates(data)
        if any('num_group' in col for col in data.columns): # Check if 'num_group' column exists
            print('action! select one file num_group')
            data=transforms(data,name)
            data=data.drop_duplicates(subset=['case_id'])
            print('missing')
            data=sparse(data)
            data=missing(data)
            print('MI Scores...')
            data=miscores_index_all(data,base)
            #data=reduce_usage(data)
            print('finished')
            gc.collect()
        else:
            print('action! select one file non-num_group')
            data=data.drop_duplicates(subset=['case_id']) 
            print('missing')
            data=sparse(data)
            data=missing(data)
            print('MI Scores...')
            data=miscores_index_all(data,base)
            #data=reduce_usage(data)
            print('finished')
            gc.collect()
        return data

    elif isinstance(paths, list):  # If multiple file paths are provided
        data_frames = []
        for path in paths:
            data = pd.read_parquet(path)
            set_table_dtypes(data)
            data=sparse(data)
            data=outliers(data)
            data = handle_dates(data)
            if any('num_group' in col for col in data.columns):  # Check if 'num_group' column exists
                print('action!select multi files num_group')
                data=transforms(data,name)
                data=data.drop_duplicates(subset=['case_id'])
                print('action!append')
                data_frames.append(data)
                del data
                print('finished')
                gc.collect()
            else:
                print('action! select multi files non-num_group')
                data=data.drop_duplicates(subset=['case_id'])
                data_frames.append(data)
                del data
                print('finished')
                gc.collect()
        together = pd.concat(data_frames)  # Concatenate all data frames at once
        del data_frames
        print('missing')
        together=sparse(together)
        together=missing(together)
        print('MI Scores...')
        together=miscores_index_all(together,base)
        return together

# %%
def reduce_usage(df):

    for col in df.columns:
        
        col_type = df[col].dtype
        
        # Skip columns of type 'category'
        if col_type == "category":
            continue
        
        # Skip columns of type 'datetime'
        if col_type == "datetime64[ns]":
            continue
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            continue
            
    return df

# %%
def remove_corr(df, threshold=0.8):
    # 筛选出数值列
    nums = df.select_dtypes(exclude=['category', 'object']).columns
    cols_to_skip = ["target", "case_id", "WEEK_NUM"]
    
    # 如果没有数值列，则直接返回原始 DataFrame
    if len(nums) == 0:
        return df
    
    # 选取数值列构建 DataFrame
    df2 = df[nums]
    
    # 计算相关性矩阵
    corr_matrix = df2.corr().abs()
    
    cols_to_remove = set(corr_matrix.columns[corr_matrix.isnull().all()])
    
    # 删除相关系数矩阵中全是 NaN 值的行和列
    corr_matrix = corr_matrix.dropna(axis=0, how='all').dropna(axis=1, how='all')
    

    # 生成上三角矩阵
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    for col in upper_triangle.columns:
        if col in cols_to_skip:
            continue
        # 计算相关列
        correlated_cols = upper_triangle.index[upper_triangle[col] > threshold].tolist()
        for correlated_col in correlated_cols:
            # 对比缺失值数量
            if df[correlated_col].isnull().sum() <= df[col].isnull().sum():
                cols_to_remove.add(col)
            else:
                cols_to_remove.add(correlated_col)
    
    # 构建保留列的列表
    cols_to_keep = [col for col in df.columns if col not in cols_to_remove]
    
    # 返回删除相关列后的 DataFrame
    df = df[cols_to_keep]
    
    return df

# %%
#MI Scores
def mi_scores(X,y):
    for col in X.columns:
        if X[col].dtype in ['category','object']:
            X[col],_=X[col].factorize()
    discrete_features=X.dtypes==int
    mi_scores=mutual_info_classif(X,y,discrete_features=discrete_features)
    mi_scores=pd.DataFrame({'MI Scores':mi_scores},index=X.columns)
    mi_scores=mi_scores.sort_values(by='MI Scores',ascending=False)
    return mi_scores
def miscores_index_all(df,base):
    test=df.dropna()
    test=pd.merge(test,base[['case_id','target']],on='case_id',how='left')
    X=test.sample(frac=0.5)
    y=X.pop('target')
    keep_cols=mi_scores(X,y).query('`MI Scores`>0.0001').index.tolist()
    if 'case_id' not in keep_cols:
        keep_cols.append('case_id')
    df=df[keep_cols]
    return df

# %%
cols=[]

# %%
#选它
base=pd.read_parquet('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_base.parquet')

# %%
set_table_dtypes(base)

# %%
base['month_decision']=base['date_decision'].dt.month
base['weekday_decision']=base['date_decision'].dt.weekday
base['day_decision']=base['date_decision'].dt.day
base['day_of_year'] = base['date_decision'].dt.dayofyear

# %%
cols.append(base.columns)

# %%
#选它
person1=pd.read_parquet('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_person_1.parquet')
set_table_dtypes(person1)

# %%
person1=person1[person1['num_group1']==0]

# %%
person1=missing(person1)
person1=sparse(person1)

# %%
person1=outliers(person1)

# %%
#没有用
def person1_date(df):
    df = pd.merge(df, base[['case_id', 'date_decision']], on='case_id', how='left') 
    for col in df.columns:
        if col in ['date_decision']:
            df[col] = pd.to_datetime(df[col])

        if col.endswith("D"):
            # Calculate the difference in days for "date_decision" - col
            new_col_name_1 = col + '_date_diff'
            df[new_col_name_1] = (df["date_decision"] - df[col]).dt.days

    # Drop the original date columns and original columns ending with "D"
    cols_to_drop = [col for col in df.columns if col.endswith("D")]
    cols_to_drop += ['date_decision',]
    df = df.drop(columns=cols_to_drop)
    return df

# %%
person1['incometype_1044T']=person1['incometype_1044T'].replace(['HANDICAPPED_2','HANDICAPPED_3'],'HANDICAPPED')

# %%
person1['safeguarantyflag_411L']=person1['safeguarantyflag_411L'].astype('float32')

# %%
person1.head()
# Out:
#     case_id birth_259D education_927M empl_employedfrom_271D  \
# 0         0 1986-07-01     P97_36_170             2017-09-15
# 4         1 1957-08-01     P97_36_170             2008-10-29
# 9         2 1974-12-01     P97_36_170             2010-02-15
# 14        3 1993-08-01    P33_146_175             2018-05-15
# 17        4 1994-01-01    P33_146_175             2014-12-15
#
#    empl_employedtotal_800L empl_industry_691L empladdr_district_926M  \
# 0                MORE_FIVE              OTHER            P142_57_166
# 4                MORE_FIVE              OTHER                    NaN
# 9                MORE_FIVE              OTHER                    NaN
# 14               MORE_FIVE              OTHER            P131_33_167
# 17               MORE_FIVE              OTHER            P62_144_102
#
#    familystate_447L incometype_1044T language1_981M  mainoccupationinc_384A  \
# 0           MARRIED    SALARIED_GOVT     P10_39_147                 10800.0
# 4          DIVORCED    SALARIED_GOVT     P10_39_147                 10000.0
# 9           MARRIED         EMPLOYED     P10_39_147                 14000.0
# 14          MARRIED         EMPLOYED     P10_39_147                 10000.0
# 17          MARRIED         EMPLOYED     P10_39_147                 24000.0
#
#     num_group1  personindex_1023L  persontype_1072L  persontype_792L  \
# 0            0                0.0               1.0              1.0
# 4            0                0.0               1.0              1.0
# 9            0                0.0               1.0              1.0
# 14           0                0.0               1.0              1.0
# 17           0                0.0               1.0              1.0
#
#    role_1084L  safeguarantyflag_411L sex_738L
# 0          CL                    1.0        F
# 4          CL                    1.0        M
# 9          EM                    1.0        F
# 14         CL                    1.0        F
# 17         CL                    1.0        F

# %%
person1=miscores_index_all(person1,base)

# %%
person1=person1.rename(columns={'birth_259D':'birth_259'})

# %%
person1.head()
# Out:
#     case_id  birth_259 education_927M empl_employedfrom_271D  \
# 0         0 1986-07-01     P97_36_170             2017-09-15
# 4         1 1957-08-01     P97_36_170             2008-10-29
# 9         2 1974-12-01     P97_36_170             2010-02-15
# 14        3 1993-08-01    P33_146_175             2018-05-15
# 17        4 1994-01-01    P33_146_175             2014-12-15
#
#    empl_employedtotal_800L empl_industry_691L empladdr_district_926M  \
# 0                MORE_FIVE              OTHER            P142_57_166
# 4                MORE_FIVE              OTHER                    NaN
# 9                MORE_FIVE              OTHER                    NaN
# 14               MORE_FIVE              OTHER            P131_33_167
# 17               MORE_FIVE              OTHER            P62_144_102
#
#    familystate_447L incometype_1044T language1_981M  mainoccupationinc_384A  \
# 0           MARRIED    SALARIED_GOVT     P10_39_147                 10800.0
# 4          DIVORCED    SALARIED_GOVT     P10_39_147                 10000.0
# 9           MARRIED         EMPLOYED     P10_39_147                 14000.0
# 14          MARRIED         EMPLOYED     P10_39_147                 10000.0
# 17          MARRIED         EMPLOYED     P10_39_147                 24000.0
#
#     num_group1  personindex_1023L  persontype_1072L  persontype_792L  \
# 0            0                0.0               1.0              1.0
# 4            0                0.0               1.0              1.0
# 9            0                0.0               1.0              1.0
# 14           0                0.0               1.0              1.0
# 17           0                0.0               1.0              1.0
#
#    role_1084L  safeguarantyflag_411L sex_738L
# 0          CL                    1.0        F
# 4          CL                    1.0        M
# 9          EM                    1.0        F
# 14         CL                    1.0        F
# 17         CL                    1.0        F

# %%
cols.append(person1.columns)

# %%
#person1第二种方式

# %%
person1=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_person_1.parquet','person1')

# %%
person1.shape
# Out:
# (1526659, 20)

# %%
cols.append(person1.columns)

# %%
bureaub21=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_b_1.parquet','bureaub21')
# Out:
# action! select one file num_group
# coming...
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# missing
# finished

# %%
bureaub21.shape
# Out:
# (36500, 163)

# %%
cols.append(bureaub21.columns)

# %%
bureaub22=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_b_2.parquet','bureaub22')
# Out:
# action! select one file num_group
# coming...
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# missing
# finished

# %%
bureaub22.shape
# Out:
# (36447, 17)

# %%
bureaub22.head()
# Out:
#      case_id  pmts_date_1107D_date_diff  pmts_date_1107D_birth_diff  \
# 0        467                         54                       23878
# 30      1445                       1097                       15994
# 113     1934                        128                       23452
# 192     3159                         76                       23025
# 195     3208                        564                       22294
#
#      num_group1_bureaub22_max  num_group1_bureaub22_count  \
# 0                           2                          30
# 30                          4                          83
# 113                         2                          79
# 192                         0                           3
# 195                         0                          15
#
#      num_group2_bureaub22_max  num_group2_bureaub22_count  \
# 0                          26                          30
# 30                         35                          83
# 113                        36                          79
# 192                         2                           3
# 195                        14                          15
#
#      pmts_dpdvalue_108P_max  pmts_dpdvalue_108P_median  \
# 0                       0.0                        0.0
# 30                 200418.0                        0.0
# 113                342432.0                   262886.0
# 192                     0.0                        0.0
# 195                  1341.0                        0.0
#
#      pmts_dpdvalue_108P_mean  pmts_dpdvalue_108P_first  \
# 0                   0.000000                       0.0
# 30              10363.111328                       0.0
# 113            260334.859375                  249912.0
# 192                 0.000000                       0.0
# 195                89.400002                       0.0
#
#      pmts_dpdvalue_108P_last  pmts_pmtsoverdue_635A_max  \
# 0                        0.0                   0.000000
# 30                       0.0                   7.200000
# 113                 275859.0                 526.799988
# 192                      0.0                   0.000000
# 195                      0.0                   5.200000
#
#      pmts_pmtsoverdue_635A_median  pmts_pmtsoverdue_635A_mean  \
# 0                        0.000000                    0.000000
# 30                       0.000000                    0.898765
# 113                    312.299988                  312.421631
# 192                      0.000000                    0.000000
# 195                      0.000000                    0.346667
#
#      pmts_pmtsoverdue_635A_first  pmts_pmtsoverdue_635A_last
# 0                       0.000000                    0.000000
# 30                      0.000000                    0.000000
# 113                    94.800003                  526.799988
# 192                     0.000000                    0.000000
# 195                     0.000000                    0.000000

# %%
cols.append(bureaub22.columns)

# %%
person2=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_person_2.parquet','person2')
# Out:
# action! select one file num_group
# coming...
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# got it！
# missing
# finished

# %%
person2.shape
# Out:
# (1435105, 8)

# %%
person2.head()
# Out:
#     case_id  addres_role_871L_n  conts_role_79M_n conts_role_79M_last  \
# 0         5                   0                 1            a55475b1
# 1         6                   2                 3            a55475b1
# 9         7                   0                 1            a55475b1
# 10        8                   0                 1            a55475b1
# 11        9                   0                 1            a55475b1
#
#     empls_economicalst_849M_n empls_economicalst_849M_last  \
# 0                           1                     a55475b1
# 1                           2                     a55475b1
# 9                           1                     a55475b1
# 10                          1                     a55475b1
# 11                          1                     a55475b1
#
#     num_group1_person2_max  num_group1_person2_count  num_group2_person2_max  \
# 0                        0                         1                       0
# 1                        1                         8                       5
# 9                        0                         1                       0
# 10                       0                         1                       0
# 11                       0                         1                       0
#
#     num_group2_person2_count  relatedpersons_role_762T_n
# 0                          1                           0
# 1                          8                           1
# 9                          1                           0
# 10                         1                           0
# 11                         1                           0

# %%
cols.append(person2.columns)

# %%
applprev2=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_applprev_2.parquet','applprev2')

# %%
applprev2.shape

# %%
cols.append(applprev2.columns)

# %%
debitcard=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_debitcard_1.parquet','debitcard')

# %%
debitcard.shape

# %%
debitcard.head()

# %%
cols.append(debitcard.columns)

# %%
deposit=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_deposit_1.parquet','deposit')

# %%
deposit.shape

# %%
cols.append(deposit.columns)

# %%
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_static_0_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_static_0_1.parquet',
             ]
static=read_file(file_paths,'static')

# %%
static.shape

# %%
cols.append(static.columns)

# %%
stativcv0=read_file('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_static_cb_0.parquet','stativcv0')

# %%
stativcv0.shape

# %%
stativcv0.columns

# %%
cols.append(stativcv0.columns)

# %%
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_applprev_1_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_applprev_1_1.parquet',
             ]
applprev1=read_file(file_paths,'applprev1')

# %%
applprev1.shape

# %%
cols.append(applprev1.columns)

# %%
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_1.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_2.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_3.parquet',
             ]
bureau=read_file(file_paths,'bureau')

# %%
# bureau定制
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_1.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_2.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_1_3.parquet',
             ]

columns = ['case_id','refreshdate_3813885D',]
# 定义空 DataFrame 存储最终结果
bureau = pd.DataFrame()

# 逐个处理数据集并合并
for file_path in file_paths:
    # 读取数据集
    data = pd.read_parquet(file_path,columns=columns)
    # 对加载的数据进行一系列处理
    set_table_dtypes(data)
    data=handle_dates(data)
    data=outliers(data)
    data=transforms(data,'bureau')
    data.drop_duplicates(subset=['case_id'],inplace=True)
    gc.collect()
    #miss_sparse(data)
    
    # 将处理后的数据追加到最终结果中
    bureau = pd.concat([bureau, data])
    del data
    gc.collect()

# %%
bureau.shape

# %%
bureau.head()

# %%
cols.append(bureau.columns)

# %%
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_1.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_10.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_2.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_3.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_4.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_5.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_6.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_7.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_8.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_9.parquet'
              
             ]
bureau2=read_file(file_paths,'bureau2')

# %%
bureau2.shape

# %%
cols.append(bureau2.columns)

# %%
# 定义文件路径列表
file_paths = ['/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_0.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_1.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_10.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_2.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_3.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_4.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_5.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_6.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_7.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_8.parquet',
              '/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_credit_bureau_a_2_9.parquet'
              
             ]
columns = ['case_id','pmts_month_158T',]
# 定义空 DataFrame 存储最终结果
bureau2 = pd.DataFrame()

# 逐个处理数据集并合并
for file_path in file_paths:
    # 读取数据集
    data = pd.read_parquet(file_path,columns=columns)
    # 对加载的数据进行一系列处理
    set_table_dtypes(data)
    data=handle_dates(data)
    data=outliers(data)
    data=transforms(data,'bureau2')  # 为所有数据集设置相同的标识符
    data.drop_duplicates(subset=['case_id'],inplace=True)
    
    # 将处理后的数据追加到最终结果中
    bureau2 = pd.concat([bureau2, data])
    del data
    gc.collect()

# %%
bureau2.shape

# %%
bureau2.head()

# %%
cols.append(bureau2.columns)

# %%
#选它
taxa=pd.read_parquet('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_tax_registry_a_1.parquet')
taxb=pd.read_parquet('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_tax_registry_b_1.parquet')
taxc=pd.read_parquet('/kaggle/input/home-credit-credit-risk-model-stability/parquet_files/train/train_tax_registry_c_1.parquet')

# %%
taxa.columns=['case_id','tax_amount','tax_name','num_group1','tax_dateD']
taxb.columns=['case_id','tax_amount','tax_dateD','tax_name','num_group1']
taxc.columns=['case_id','tax_name','num_group1','tax_amount','tax_dateD']

# %%
#选它
tax=pd.concat([taxc,taxa,taxb],axis=0)
del taxa,taxb,taxc

# %%
set_table_dtypes(tax)

# %%
tax=outliers(tax)

# %%
tax=handle_dates(tax)

# %%
def transform_cols(df, group,df_name):
    num_cols = df.select_dtypes(include=['int', 'float']).columns
    obj_cols = df.select_dtypes(include=['object', 'category']).columns

    # 处理数值型特征
    for col in num_cols:
        if col not in ["target", "case_id", "WEEK_NUM", 'num_group1', 'num_group2']:
            grouped_series = df.groupby(group)[col]
            df[f"{col}_max"] = grouped_series.transform('max')
            df[f"{col}_median"] = grouped_series.transform('median')
            df[f"{col}_mean"] = grouped_series.transform('mean')
            df[f"{col}_first"] = grouped_series.transform('first')
            df[f"{col}_last"] = grouped_series.transform('last')
            df.drop(columns=[col], inplace=True)  # 删除原始列

    # 处理非数值型特征
    for col in obj_cols:
        if col not in ["target", "case_id", "WEEK_NUM", 'num_group1', 'num_group2']:
            grouped_series = df.groupby(group)[col]
            df[f"{col}_count"] = grouped_series.transform('count')
            df[f"{col}_n"] = grouped_series.transform('nunique')
            df[f"{col}_first"] = grouped_series.transform('first')
            df[f"{col}_last"] = grouped_series.transform('last')
            df.drop(columns=[col], inplace=True)  # 删除原始列

    # 处理包含'num_group'的特征列
    for col in df.columns:
        if 'num_group' in col:
            grouped_series = df.groupby(group)[col]
            df[f"{col}_{df_name}_max"] = grouped_series.transform('max')
            df[f"{col}_{df_name}_count"] = grouped_series.transform('count')
            df.drop(columns=[col],inplace=True)

# %%
transform_cols(tax,'case_id','tax')

# %%
tax.drop_duplicates(subset=['case_id'],keep='first',inplace=True)

# %%
tax.shape

# %%
cols.append(tax.columns)

# %%
merged_list = [item for sublist in cols for item in sublist]

# %%
cols=list(set(merged_list))

# %%
len(cols)

# %%
del all1

# %%
all1=pd.merge(base,person1,on='case_id',how='left')

# %%
all1=pd.merge(all1,applprev1,on='case_id',how='left')
all1=pd.merge(all1,static,on='case_id',how='left')

# %%
all1=pd.merge(all1,stativcv0,on='case_id',how='left')
all1=pd.merge(all1,tax,on='case_id',how='left')

# %%
all1=pd.merge(all1,bureau,on='case_id',how='left')

# %%
all1=pd.merge(all1,bureau2,on='case_id',how='left')

# %%
all1=pd.merge(all1,bureaub21,on='case_id',how='left')
all1=pd.merge(all1,bureaub22,on='case_id',how='left')

# %%
all1=pd.merge(all1,deposit,on='case_id',how='left')
all1=pd.merge(all1,applprev2,on='case_id',how='left')

# %%
all1=pd.merge(all1,person2,on='case_id',how='left')
all1=pd.merge(all1,debitcard,on='case_id',how='left')

# %%
all1.shape

# %%
#目标编码
col=['empladdr_district_926M','incometype_1044T','education_927M','lastst_736L','lastrejectreason_759M','lastrejectreasonclient_4145040M','credtype_322L']
X_encode=all1.sample(frac=0.2,random_state=0)
y_encode=X_encode.pop('target')
X_pretrain=all1.drop(X_encode.index)
y_pretrain=X_pretrain.pop('target')
encoder=MEstimateEncoder(cols=col,m=500)
encoder.fit(X_encode[col],y_encode)
X_pretrain_encoded=encoder.transform(X_pretrain[col])
X_pretrain_encoded.columns = [f'{col}_encoded' for col in X_pretrain_encoded.columns] 
all1 = pd.concat([X_pretrain, X_pretrain_encoded,pd.DataFrame(y_pretrain, columns=['target'])], axis=1)

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        # Skip columns of type 'category'
        if col_type == "category":
            continue
        
        # Skip columns of type 'datetime'
        if col_type == "datetime64[ns]":
            continue
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            continue
            
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
 all1=reduce_mem_usage(all1)

# %%
all1.shape
# Out:
# (1526659, 274)

# %%
all1=pd.read_csv('/kaggle/input/credic/274-less -newnew.csv')

# %%
all1=remove_corr(all1)

# %%
all1.shape
# Out:
# (1526659, 368)

# %%
all1.select_dtypes(include=['object', 'category']).columns

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from category_encoders import TargetEncoder


onehot_cols = []
ordinal_cols = []
target_cols = []

onehot_encoders = {}
#ordinal_encoders = {}
target_encoders = {}

for col in all1.select_dtypes(include=['object', 'category']).columns:
    unique_count = all1[col].nunique()

    if unique_count < 5:
        onehot_cols.append(col)  # 记录列名
        encoder = OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore', dtype=np.int8)
        transformed_data = encoder.fit_transform(all1[[col]])
        all1 = all1.drop(columns=[col])  # 删除原特征列
        all1 = pd.concat([all1, pd.DataFrame(transformed_data, columns=encoder.get_feature_names_out([col]))], axis=1)
        onehot_encoders[col] = encoder

    elif 5 <= unique_count < 50:
        ordinal_cols.append(col)  # 记录列名
        encoder = OrdinalEncoder(handle_unknown='ignore', dtype=np.float32)
        all1[col] = encoder.fit_transform(all1[[col]])

    else:
        target_cols.append(col)  # 记录列名
        encoder = TargetEncoder(smoothing=100)
        all1[col] = encoder.fit_transform(all1[col], all1['target'])
        target_encoders[col] = encoder
print("\nOneHot Encoded Columns:")
print(onehot_cols)
print("\nOrdinal Encoded Columns:")
print(ordinal_cols)
print("\nTarget Encoded Columns:")
print(target_cols)
# Out:
# OneHot Encoded Columns:
# ['education_927M_first', 'education_927M_last', 'familystate_447L_first', 'familystate_447L_last', 'incometype_1044T_first', 'incometype_1044T_last', 'language1_981M_first', 'language1_981M_last', 'role_1084L_first', 'role_1084L_last', 'sex_738L_first', 'sex_738L_last', 'type_25L_first', 'type_25L_last', 'cancelreason_3545846M_first', 'cancelreason_3545846M_last', 'credtype_587L_first', 'credtype_587L_last', 'education_1138M_first', 'education_1138M_last', 'familystate_726L_first', 'familystate_726L_last', 'inittransactioncode_279L_first', 'inittransactioncode_279L_last', 'isbidproduct_390L_first', 'isbidproduct_390L_last', 'postype_4733339M_first', 'postype_4733339M_last', 'rejectreason_755M_first', 'rejectreason_755M_last', 'rejectreasonclient_4145042M_first', 'rejectreasonclient_4145042M_last', 'status_219L_first', 'status_219L_last', 'credtype_322L', 'disbursementtype_67L', 'inittransactioncode_186L', 'lastapprcommoditycat_1041M', 'lastcancelreason_561M', 'lastrejectcommoditycat_161M', 'lastrejectreason_759M', 'lastrejectreasonclient_4145040M', 'lastst_736L', 'description_5085714M', 'education_1103M', 'maritalst_385M', 'requesttype_4525192L', 'classificationofcontr_1114M_first', 'classificationofcontr_1114M_last', 'contracttype_653M_first', 'contracttype_653M_last', 'credor_3940957M_first', 'credor_3940957M_last', 'periodicityofpmts_997M_first', 'periodicityofpmts_997M_last', 'pmtmethod_731M_first', 'pmtmethod_731M_last', 'purposeofcred_722M_first', 'purposeofcred_722M_last', 'subjectrole_326M_first', 'subjectrole_326M_last', 'subjectrole_43M_first', 'subjectrole_43M_last', 'conts_type_509L_first', 'conts_type_509L_last']
#
# Ordinal Encoded Columns:
# []
#
# Target Encoded Columns:
# ['date_decision', 'tax_name_first', 'tax_name_last']

# %%
import joblib
joblib.dump(onehot_encoders, 'onehot_encoders.pkl')
#joblib.dump(ordinal_encoders, 'ordinal_encoders.pkl')
joblib.dump(target_encoders, 'target_encoders.pkl')
# Out:
# ['target_encoders.pkl']

# %%
(all1.isnull().sum(axis=1)>20).sum()

# %%
all1.to_csv('274-less.csv',index=False)

# %%
all1.columns.tolist()

# %%
all1.select_dtypes(['object','category']).columns
# Out:
# Index([], dtype='object')

# %%
for col in all1.columns:
    if all1[col].dtype in ['category','object']:
        all1[col],_=all1[col].factorize()
#all1=change32(all1)

# %%
all1.shape
# Out:
# (1526659, 368)

# %%
#diy一个评分标准
from sklearn.metrics import make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score
def stability_metric(y_true,y_pred):
    gini_in_time=[]
    unique_weeks=np.unique(X_test['WEEK_NUM'])
    for week_num in unique_weeks:
        week_indices=np.where(X_test['WEEK_NUM']==week_num)[0]
        y_true_week=y_true.iloc[week_indices]
        y_pred_week=y_pred.iloc[week_indices]
        if (y_true_week == 0).all():
            continue
        gini = 2 * roc_auc_score(y_true_week, y_pred_week) - 1
        gini_in_time.append(gini)
   
    #fit a linear regression
    x=np.arange(len(gini_in_time))
    y=gini_in_time
    a, b = np.polyfit(x, y, 1)
    y_hat = a * x + b
    residuals = y - y_hat
    res_std = np.std(residuals)
    avg_gini = np.mean(gini_in_time)
    #final
    stability=avg_gini+88*min(0,a)-0.5*res_std
    return stability
stability_scorer=make_scorer(stability_metric,greater_is_better=True)

# %%
import wandb
wandb.init(project='credit',
           name='',
           #config=params,\
           notes='')

# %%
category_cols=['incometype_1044T_last', 'incometype_1044T_first', 'sex_738L_last',
       'sex_738L_first', 'empladdr_district_926M_first',
       'education_927M_first', 'language1_981M_first', 'language1_981M_last',
       'role_1084L_first', 'type_25L_last', 'role_1084L_last',
       'empladdr_zipcode_114M_last', 'education_927M_last',
       'empladdr_district_926M_last', 'type_25L_first', 'status_219L_last',
       'cancelreason_3545846M_last', 'rejectreason_755M_last',
       'rejectreasonclient_4145042M_last', 'status_219L_first',
       'cancelreason_3545846M_first', 'rejectreason_755M_first',
       'rejectreasonclient_4145042M_first', 'education_1138M_first',
       'education_1138M_last', 'inittransactioncode_279L_last',
       'credtype_587L_last', 'familystate_726L_first', 'familystate_726L_last',
       'postype_4733339M_last', 'inittransactioncode_279L_first',
       'credtype_587L_first', 'postype_4733339M_first',
       'lastrejectreason_759M', 'lastst_736L', 'lastcancelreason_561M',
       'lastrejectreasonclient_4145040M', 'previouscontdistrict_112M',
       'lastapprcommoditycat_1041M', 'lastrejectcommoditycat_161M',
       'lastapprcommoditytypec_5251766M', 'opencred_647L',
       'lastrejectcommodtypec_5251769M', 'credtype_322L',
       'inittransactioncode_186L', 'disbursementtype_67L',
       'twobodfilling_608L', 'education_1103M', 'description_5085714M',
       'maritalst_385M', 'maritalst_893M', 'education_88M', 'tax_name_first',
       'tax_name_last', 'contractst_516M_first', 'credor_3940957M_first',
       'contractst_516M_last', 'periodicityofpmts_997M_first',
       'purposeofcred_722M_first', 'credor_3940957M_last',
       'classificationofcontr_1114M_first', 'contracttype_653M_first',
       'subjectrole_326M_last', 'pmtmethod_731M_first', 'pmtmethod_731M_last',
       'subjectrole_43M_first', 'subjectrole_326M_first',
       'classificationofcontr_1114M_last', 'purposeofcred_722M_last',
       'contracttype_653M_last', 'subjectrole_43M_last',
       'conts_type_509L_last', 'conts_type_509L_first',
       'cacccardblochreas_147M_first', 'addres_district_368M_first',
       'addres_district_368M_last', 'empls_economicalst_849M_first',
       'conts_role_79M_last']

# %%
df_train=all1.iloc[:100000]
df_valid=all1.iloc[700000:1000000]
#df_test=all1.iloc[800000:900000]

y_train=df_train['target']
X_train=df_train.drop(columns=['target','case_id','date_decision'])
y_valid=df_valid['target']
X_valid=df_valid.drop(columns=['target','case_id','date_decision'])
#y_test=df_test['target']
#X_test=df_test.drop(columns=['target','case_id','date_decision'])

X_train[category_cols] = X_train[category_cols].astype('category')
X_valid[category_cols] = X_valid[category_cols].astype('category')
#X_test[category_cols] = X_test[category_cols].astype('category')

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "auc",
    "max_depth": 5,  
    "learning_rate": 0.05,
    'subsample_freq':9,
    'subsample':0.65,
    #0.8144028756010205
    "num_boost_round":3000, 
    "colsample_bytree": 0.625,
    "colsample_bynode": 0.875,
    "random_state": 42,
    "reg_alpha": 7.35,
    "reg_lambda": 6.55,
    "extra_trees":True,
    'num_leaves':55, 
    "verbose": -1,
    'early_stopping_round':100,
    'min_child_samples':4928,
    #'is_unbalalce':True,
    'scale_pos_weight':30,
    'device':'cpu',
    #'min_child_weight':0.06703326435611615,
    #'min_split_gain':0.21805530921304175,
    #后面是dart的参数
    #'drop_rate':0.1,
    #'skip_drop':0.5,
    #'uniform_drop':False,
    #'xgboost_dart_mode':False,
   
}

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from catboost import CatBoostClassifier, Pool

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import TimeSeriesSplit, GroupKFold, StratifiedGroupKFold
from sklearn.metrics import make_scorer,roc_auc_score

# %%
#optuna超参数调优
from optuna.samplers import RandomSampler
import optuna
def objective(trial):
    params={
        "boosting_type": "gbdt",
        "objective": "binary",
        "metric": "auc",
        "max_depth": trial.suggest_int("max_depth", 5,10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01,0.05,step=0.005),
        "subsample_freq": trial.suggest_int("subsample_freq", 3, 10),
        "subsample": trial.suggest_float("subsample", 0.5,0.8,step=0.01),
        "num_boost_round": 3500,
        #'num_boost_round': trial.suggest_int('num_boost_roung',2000,4500),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 0.9,step=0.005),
        "colsample_bynode": trial.suggest_float("colsample_bynode", 0.5, 0.9,step=0.005),
        "random_state": 42,
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 20,step=0.01),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 35,step=0.01),
        "extra_trees": True,
        "num_leaves": trial.suggest_int("num_leaves", 30, 60),
        "verbose": -1,
        "min_child_samples": trial.suggest_int("min_child_samples", 1000, 8000),
        'scale_pos_weight':30,
        #'is_unbalalce':True,
        #"min_child_weight": trial.suggest_float("min_child_weight", 0.1, 0.15),
        #'min_split_gain':trial.suggest_float('min_split_gain', 0.1, 0.5),
        'device':'cpu'
    }
    train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=category_cols)
    model=lgb.LGBMClassifier(**params)
    model.fit(X_train,y_train,eval_set=[(X_valid,y_valid)],callbacks=[lgb.log_evaluation(200), lgb.early_stopping(100)],
              )
    y_pred = model.predict_proba(X_test)[:, 1]
    y_pred=pd.Series(y_pred,index=y_test.index)
    score=stability_metric(y_test,y_pred)
    wandb.log({'score': score,'auc':model.evals_result_['valid_0']['auc'][-1]})
    return score
pruner=optuna.pruners.MedianPruner(
    n_startup_trials=5, n_warmup_steps=500, interval_steps=1)
study=optuna.create_study(direction='maximize',pruner=pruner)
study.optimize(objective,n_trials=400,)
print('bset trial:')
best_trial=study.best_trial
print('Value:{}'.format(best_trial.value))
print('Params:')
for key,value in best_trial.params.items():
    print('{}:{}'.format(key,value))

# %%
df_train=all1.iloc[900000:]
#df_train[category_cols] = df_train[category_cols].astype('category')

# %%
for col in category_cols:
    df_train[col] = df_train[col].cat.add_categories('unknown')
df_train[category_cols] = df_train[category_cols].fillna('unknown')

# %%
#分层分组抽样
y= all1["target"]
weeks = all1["WEEK_NUM"]
df_train= all1.drop(columns=["target", "case_id", "WEEK_NUM",
                             #'date_decision'
                            ])
cv = StratifiedGroupKFold(n_splits=10, shuffle=False)

fitted_models_cat = []
fitted_models_lgb = []

cv_scores_cat = []
cv_scores_lgb = []

stability_results_cat = []
stability_results_lgb = []

feature_importance_lgb = []

fold = 0
for idx_train, idx_valid in cv.split(df_train, y,groups=weeks):
    
    df_res_cat = pd.DataFrame()
    df_res_lgb = pd.DataFrame()
    
    X_train, y_train = df_train.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid= df_train.iloc[idx_valid], y.iloc[idx_valid]
    
    #df_res_cat['WEEK_NUM'] = list(week_valid)
    df_res_cat['target'] = list(y_valid)
    df_res_cat['fold'] = fold
    
    
    #df_res_lgb['WEEK_NUM'] = list(week_valid)
    df_res_lgb['target'] = list(y_valid)
    df_res_lgb['fold'] = fold
    
    fold += 1
    
    
    train_pool = Pool(X_train, y_train,
                      #cat_features=category_cols
                     )
    val_pool = Pool(X_valid, y_valid,
                    #cat_features=category_cols
                   )
    
    clf = CatBoostClassifier(eval_metric='AUC', task_type='CPU', learning_rate=0.03, iterations=1000,
                             class_weights=[1,30]
                            )
    
    random_seed=3107
    
    clf.fit(train_pool, eval_set=val_pool,verbose=100)
    fitted_models_cat.append(clf)
    y_pred_valid = clf.predict_proba(X_valid)[:,1]
    auc_score = roc_auc_score(y_valid, y_pred_valid)
    cv_scores_cat.append(auc_score)
    
    df_res_cat['score'] = list(y_pred_valid)
    
    
    train_data = lgb.Dataset(X_train, label=y_train,)
    model = lgb.LGBMClassifier(**params)
    model.fit(
        X_train,y_train,
        #categorical_feature=category_cols,
        eval_set = [(X_valid, y_valid)],
        #callbacks=[wandb_callback()]
        callbacks=[lgb.log_evaluation(200), lgb.early_stopping(100)] 
    )
    
    fitted_models_lgb.append(model)
    y_pred_valid = model.predict_proba(X_valid)[:,1]
    #auc指标
    auc_score = roc_auc_score(y_valid, y_pred_valid)
    cv_scores_lgb.append(auc_score)
    #特征重要性
    fold_importance = model.feature_importances_
    feature_importance_lgb.append(fold_importance)
    
    
    df_res_lgb['score'] = list(y_pred_valid)
    
    #stability_results_cat.append(df_res_cat)
    stability_results_lgb.append(df_res_lgb)

#计算特征重要性
avg_feature_importance_lgb = np.mean(feature_importance_lgb, axis=0)
sorted_idx = np.argsort(avg_feature_importance_lgb)[::-1]
print('Feature importance ranking')
for i, idx in enumerate(sorted_idx):
    print(f"{i + 1}. Feature '{df_train.columns[idx]}' - Importance: {avg_feature_importance_lgb[idx]}")

    
    
print("Catboost CV AUC scores: ", cv_scores_cat)
print("Maximum Catboost CV AUC score: ", max(cv_scores_cat))


print("Lightgbm CV AUC scores: ", cv_scores_lgb)
print("Maximum Lightgbm CV AUC score: ", max(cv_scores_lgb))
# Out:
# 0:	test: 0.8259318	best: 0.8259318 (0)	total: 1.07s	remaining: 17m 45s
# 100:	test: 0.8825763	best: 0.8825763 (100)	total: 1m 39s	remaining: 14m 43s
# 200:	test: 0.8918033	best: 0.8918033 (200)	total: 3m 20s	remaining: 13m 15s
# 300:	test: 0.8958618	best: 0.8958618 (300)	total: 4m 55s	remaining: 11m 25s
# 400:	test: 0.8984672	best: 0.8984672 (400)	total: 6m 32s	remaining: 9m 46s
# 500:	test: 0.9007896	best: 0.9007896 (500)	total: 8m 10s	remaining: 8m 8s
# 600:	test: 0.9026180	best: 0.9026180 (600)	total: 9m 47s	remaining: 6m 29s
# 700:	test: 0.9039527	best: 0.9039527 (700)	total: 11m 22s	remaining: 4m 51s
# 800:	test: 0.9047105	best: 0.9047105 (800)	total: 12m 55s	remaining: 3m 12s
# 900:	test: 0.9054245	best: 0.9054245 (900)	total: 14m 26s	remaining: 1m 35s
# 999:	test: 0.9059423	best: 0.9059423 (997)	total: 15m 58s	remaining: 0us
#
# bestTest = 0.9059423304
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.893763
# [400]	valid_0's auc: 0.901228
# [600]	valid_0's auc: 0.903731
# [800]	valid_0's auc: 0.905177
# [1000]	valid_0's auc: 0.906091
# [1200]	valid_0's auc: 0.906683
# [1400]	valid_0's auc: 0.907137
# [1600]	valid_0's auc: 0.907491
# [1800]	valid_0's auc: 0.907736
# [2000]	valid_0's auc: 0.907877
# [2200]	valid_0's auc: 0.907996
# [2400]	valid_0's auc: 0.90818
# 0:	test: 0.8156660	best: 0.8156660 (0)	total: 1.12s	remaining: 18m 38s
# 100:	test: 0.8752970	best: 0.8752970 (100)	total: 1m 40s	remaining: 14m 50s
# 200:	test: 0.8837675	best: 0.8837675 (200)	total: 3m 19s	remaining: 13m 13s
# 300:	test: 0.8876191	best: 0.8876191 (300)	total: 4m 54s	remaining: 11m 23s
# 400:	test: 0.8903132	best: 0.8903132 (400)	total: 6m 32s	remaining: 9m 46s
# 500:	test: 0.8924898	best: 0.8924898 (500)	total: 8m 11s	remaining: 8m 9s
# 600:	test: 0.8947163	best: 0.8947163 (600)	total: 9m 49s	remaining: 6m 31s
# 700:	test: 0.8961348	best: 0.8961348 (700)	total: 11m 23s	remaining: 4m 51s
# 800:	test: 0.8972531	best: 0.8972589 (799)	total: 12m 58s	remaining: 3m 13s
# 900:	test: 0.8981002	best: 0.8981002 (900)	total: 14m 33s	remaining: 1m 36s
# 999:	test: 0.8986381	best: 0.8986381 (999)	total: 16m 4s	remaining: 0us
#
# bestTest = 0.8986381126
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.88575
# [400]	valid_0's auc: 0.892738
# [600]	valid_0's auc: 0.89615
# [800]	valid_0's auc: 0.897892
# [1000]	valid_0's auc: 0.898861
# [1200]	valid_0's auc: 0.899645
# [1400]	valid_0's auc: 0.900141
# [1600]	valid_0's auc: 0.900591
# [1800]	valid_0's auc: 0.900677
# [2000]	valid_0's auc: 0.901104
# [2200]	valid_0's auc: 0.901205
# [2400]	valid_0's auc: 0.901274
# 0:	test: 0.8322925	best: 0.8322925 (0)	total: 1.07s	remaining: 17m 52s
# 100:	test: 0.8849169	best: 0.8849169 (100)	total: 1m 41s	remaining: 15m 1s
# 200:	test: 0.8939412	best: 0.8939412 (200)	total: 3m 20s	remaining: 13m 15s
# 300:	test: 0.8977476	best: 0.8977476 (300)	total: 4m 56s	remaining: 11m 28s
# 400:	test: 0.9000768	best: 0.9000768 (400)	total: 6m 32s	remaining: 9m 45s
# 500:	test: 0.9020450	best: 0.9020450 (500)	total: 8m 8s	remaining: 8m 6s
# 600:	test: 0.9039544	best: 0.9039544 (600)	total: 9m 45s	remaining: 6m 28s
# 700:	test: 0.9050565	best: 0.9050565 (700)	total: 11m 25s	remaining: 4m 52s
# 800:	test: 0.9058674	best: 0.9058730 (799)	total: 13m	remaining: 3m 13s
# 900:	test: 0.9065930	best: 0.9065930 (900)	total: 14m 35s	remaining: 1m 36s
# 999:	test: 0.9070710	best: 0.9070710 (999)	total: 16m 9s	remaining: 0us
#
# bestTest = 0.9070709831
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.896185
# [400]	valid_0's auc: 0.90383
# [600]	valid_0's auc: 0.906665
# [800]	valid_0's auc: 0.908105
# [1000]	valid_0's auc: 0.908905
# [1200]	valid_0's auc: 0.909545
# [1400]	valid_0's auc: 0.909869
# [1600]	valid_0's auc: 0.910197
# [1800]	valid_0's auc: 0.910491
# [2000]	valid_0's auc: 0.910636
# 0:	test: 0.8251974	best: 0.8251974 (0)	total: 1.12s	remaining: 18m 37s
# 100:	test: 0.8893273	best: 0.8893273 (100)	total: 1m 40s	remaining: 14m 52s
# 200:	test: 0.8983827	best: 0.8983827 (200)	total: 3m 19s	remaining: 13m 13s
# 300:	test: 0.9025249	best: 0.9025249 (300)	total: 4m 58s	remaining: 11m 32s
# 400:	test: 0.9049185	best: 0.9049185 (400)	total: 6m 32s	remaining: 9m 46s
# 500:	test: 0.9068399	best: 0.9068399 (500)	total: 8m 9s	remaining: 8m 7s
# 600:	test: 0.9085318	best: 0.9085318 (600)	total: 9m 46s	remaining: 6m 29s
# 700:	test: 0.9096546	best: 0.9096607 (699)	total: 11m 22s	remaining: 4m 50s
# 800:	test: 0.9105423	best: 0.9105423 (800)	total: 12m 57s	remaining: 3m 13s
# 900:	test: 0.9111434	best: 0.9111496 (898)	total: 14m 32s	remaining: 1m 35s
# 999:	test: 0.9115770	best: 0.9115770 (999)	total: 16m 3s	remaining: 0us
#
# bestTest = 0.9115769797
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.901679
# [400]	valid_0's auc: 0.907559
# [600]	valid_0's auc: 0.909771
# [800]	valid_0's auc: 0.910852
# [1000]	valid_0's auc: 0.911675
# [1200]	valid_0's auc: 0.91215
# [1400]	valid_0's auc: 0.91244
# [1600]	valid_0's auc: 0.912661
# 0:	test: 0.8296722	best: 0.8296722 (0)	total: 1.21s	remaining: 20m 5s
# 100:	test: 0.8869433	best: 0.8869433 (100)	total: 1m 41s	remaining: 14m 59s
# 200:	test: 0.8957934	best: 0.8957934 (200)	total: 3m 20s	remaining: 13m 15s
# 300:	test: 0.8998705	best: 0.8998705 (300)	total: 4m 59s	remaining: 11m 35s
# 400:	test: 0.9025003	best: 0.9025003 (400)	total: 6m 34s	remaining: 9m 49s
# 500:	test: 0.9046470	best: 0.9046470 (500)	total: 8m 10s	remaining: 8m 8s
# 600:	test: 0.9063498	best: 0.9063499 (599)	total: 9m 51s	remaining: 6m 32s
# 700:	test: 0.9075103	best: 0.9075103 (700)	total: 11m 28s	remaining: 4m 53s
# 800:	test: 0.9083493	best: 0.9083493 (800)	total: 13m 2s	remaining: 3m 14s
# 900:	test: 0.9089447	best: 0.9089447 (900)	total: 14m 37s	remaining: 1m 36s
# 999:	test: 0.9094446	best: 0.9094492 (998)	total: 16m 9s	remaining: 0us
#
# bestTest = 0.9094491769
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.898161
# [400]	valid_0's auc: 0.90446
# [600]	valid_0's auc: 0.907056
# [800]	valid_0's auc: 0.908429
# [1000]	valid_0's auc: 0.909045
# [1200]	valid_0's auc: 0.909521
# [1400]	valid_0's auc: 0.90995
# [1600]	valid_0's auc: 0.910062
# [1800]	valid_0's auc: 0.910289
# 0:	test: 0.8317569	best: 0.8317569 (0)	total: 1.18s	remaining: 19m 40s
# 100:	test: 0.8874267	best: 0.8874267 (100)	total: 1m 41s	remaining: 15m 7s
# 200:	test: 0.8968772	best: 0.8968772 (200)	total: 3m 24s	remaining: 13m 30s
# 300:	test: 0.9010874	best: 0.9010874 (300)	total: 5m 2s	remaining: 11m 42s
# 400:	test: 0.9036227	best: 0.9036227 (400)	total: 6m 40s	remaining: 9m 58s
# 500:	test: 0.9055644	best: 0.9055644 (500)	total: 8m 19s	remaining: 8m 17s
# 600:	test: 0.9074076	best: 0.9074076 (600)	total: 9m 59s	remaining: 6m 37s
# 700:	test: 0.9086671	best: 0.9086671 (700)	total: 11m 37s	remaining: 4m 57s
# 800:	test: 0.9096209	best: 0.9096209 (800)	total: 13m 14s	remaining: 3m 17s
# 900:	test: 0.9102157	best: 0.9102157 (900)	total: 14m 47s	remaining: 1m 37s
# 999:	test: 0.9107849	best: 0.9107849 (999)	total: 16m 17s	remaining: 0us
#
# bestTest = 0.910784866
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.899649
# [400]	valid_0's auc: 0.906177
# [600]	valid_0's auc: 0.90888
# [800]	valid_0's auc: 0.910257
# [1000]	valid_0's auc: 0.911112
# [1200]	valid_0's auc: 0.911553
# [1400]	valid_0's auc: 0.911874
# [1600]	valid_0's auc: 0.91211
# [1800]	valid_0's auc: 0.912162
# Early stopping, best iteration is:
# [1722]	valid_0's auc: 0.912201
# 0:	test: 0.8391079	best: 0.8391079 (0)	total: 1.14s	remaining: 19m 2s
# 100:	test: 0.8908143	best: 0.8908143 (100)	total: 1m 39s	remaining: 14m 49s
# 200:	test: 0.9001263	best: 0.9001263 (200)	total: 3m 18s	remaining: 13m 9s
# 300:	test: 0.9040544	best: 0.9040544 (300)	total: 4m 56s	remaining: 11m 27s
# 400:	test: 0.9065920	best: 0.9065920 (400)	total: 6m 32s	remaining: 9m 46s
# 500:	test: 0.9087106	best: 0.9087106 (500)	total: 8m 8s	remaining: 8m 6s
# 600:	test: 0.9104277	best: 0.9104430 (599)	total: 9m 45s	remaining: 6m 28s
# 700:	test: 0.9116289	best: 0.9116289 (700)	total: 11m 21s	remaining: 4m 50s
# 800:	test: 0.9125493	best: 0.9125493 (800)	total: 12m 56s	remaining: 3m 12s
# 900:	test: 0.9132273	best: 0.9132273 (900)	total: 14m 29s	remaining: 1m 35s
# 999:	test: 0.9137514	best: 0.9137514 (999)	total: 16m 1s	remaining: 0us
#
# bestTest = 0.9137514306
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.903415
# [400]	valid_0's auc: 0.909943
# [600]	valid_0's auc: 0.91205
# [800]	valid_0's auc: 0.913207
# [1000]	valid_0's auc: 0.913945
# [1200]	valid_0's auc: 0.914529
# [1400]	valid_0's auc: 0.914892
# [1600]	valid_0's auc: 0.914984
# [1800]	valid_0's auc: 0.915115
# 0:	test: 0.8331107	best: 0.8331107 (0)	total: 1.39s	remaining: 23m 13s
# 100:	test: 0.8865793	best: 0.8865793 (100)	total: 1m 41s	remaining: 14m 59s
# 200:	test: 0.8950506	best: 0.8950506 (200)	total: 3m 21s	remaining: 13m 20s
# 300:	test: 0.8988044	best: 0.8988044 (300)	total: 4m 59s	remaining: 11m 35s
# 400:	test: 0.9010473	best: 0.9010473 (400)	total: 6m 37s	remaining: 9m 53s
# 500:	test: 0.9029740	best: 0.9029740 (500)	total: 8m 13s	remaining: 8m 12s
# 600:	test: 0.9047136	best: 0.9047136 (600)	total: 9m 51s	remaining: 6m 33s
# 700:	test: 0.9058661	best: 0.9058661 (700)	total: 11m 28s	remaining: 4m 53s
# 800:	test: 0.9068042	best: 0.9068042 (800)	total: 13m 2s	remaining: 3m 14s
# 900:	test: 0.9073774	best: 0.9073774 (900)	total: 14m 36s	remaining: 1m 36s
# 999:	test: 0.9079529	best: 0.9079600 (998)	total: 16m 10s	remaining: 0us
#
# bestTest = 0.9079599859
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.897181
# [400]	valid_0's auc: 0.902493
# [600]	valid_0's auc: 0.905161
# [800]	valid_0's auc: 0.90668
# [1000]	valid_0's auc: 0.907519
# [1200]	valid_0's auc: 0.908073
# [1400]	valid_0's auc: 0.908546
# [1600]	valid_0's auc: 0.908785
# [1800]	valid_0's auc: 0.908948
# [2000]	valid_0's auc: 0.90907
# 0:	test: 0.8342118	best: 0.8342118 (0)	total: 1.04s	remaining: 17m 24s
# 100:	test: 0.8884360	best: 0.8884360 (100)	total: 1m 41s	remaining: 15m 5s
# 200:	test: 0.8977089	best: 0.8977089 (200)	total: 3m 20s	remaining: 13m 17s
# 300:	test: 0.9017744	best: 0.9017744 (300)	total: 4m 56s	remaining: 11m 29s
# 400:	test: 0.9043690	best: 0.9043690 (400)	total: 6m 34s	remaining: 9m 49s
# 500:	test: 0.9066698	best: 0.9066698 (500)	total: 8m 10s	remaining: 8m 8s
# 600:	test: 0.9085527	best: 0.9085527 (600)	total: 9m 49s	remaining: 6m 31s
# 700:	test: 0.9097864	best: 0.9097864 (700)	total: 11m 25s	remaining: 4m 52s
# 800:	test: 0.9106561	best: 0.9106561 (800)	total: 13m	remaining: 3m 13s
# 900:	test: 0.9113366	best: 0.9113400 (899)	total: 14m 32s	remaining: 1m 35s
# 999:	test: 0.9118713	best: 0.9118713 (999)	total: 16m 4s	remaining: 0us
#
# bestTest = 0.9118713135
# bestIteration = 999
#
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.899987
# [400]	valid_0's auc: 0.906861
# [600]	valid_0's auc: 0.909515
# [800]	valid_0's auc: 0.910787
# [1000]	valid_0's auc: 0.911711
# [1200]	valid_0's auc: 0.912134
# [1400]	valid_0's auc: 0.912561
# [1600]	valid_0's auc: 0.912823
# [1800]	valid_0's auc: 0.913064
# [2000]	valid_0's auc: 0.913267
# Early stopping, best iteration is:
# [2004]	valid_0's auc: 0.913283
# 0:	test: 0.8343373	best: 0.8343373 (0)	total: 1.44s	remaining: 24m 2s
# 100:	test: 0.8856460	best: 0.8856460 (100)	total: 1m 40s	remaining: 14m 56s
# 200:	test: 0.8947146	best: 0.8947146 (200)	total: 3m 20s	remaining: 13m 16s
# 300:	test: 0.8986651	best: 0.8986651 (300)	total: 4m 56s	remaining: 11m 27s
# 400:	test: 0.9013993	best: 0.9013993 (400)	total: 6m 33s	remaining: 9m 47s
# 500:	test: 0.9037108	best: 0.9037108 (500)	total: 8m 12s	remaining: 8m 10s
# 600:	test: 0.9055778	best: 0.9055778 (600)	total: 9m 50s	remaining: 6m 32s
# 700:	test: 0.9066765	best: 0.9066777 (697)	total: 11m 26s	remaining: 4m 52s
# 800:	test: 0.9077000	best: 0.9077000 (800)	total: 13m 2s	remaining: 3m 14s
# 900:	test: 0.9084501	best: 0.9084518 (899)	total: 14m 39s	remaining: 1m 36s
# 999:	test: 0.9088737	best: 0.9088806 (997)	total: 16m 13s	remaining: 0us
#
# bestTest = 0.9088805988
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.897044
# [400]	valid_0's auc: 0.903936
# [600]	valid_0's auc: 0.906592
# [800]	valid_0's auc: 0.908107
# [1000]	valid_0's auc: 0.908835
# [1200]	valid_0's auc: 0.909286
# [1400]	valid_0's auc: 0.909598
# [1600]	valid_0's auc: 0.909768
# [1800]	valid_0's auc: 0.90991
# [2000]	valid_0's auc: 0.910108
# Early stopping, best iteration is:
# [2030]	valid_0's auc: 0.910163
# Feature importance ranking
# 1. Feature 'price_1097A' - Importance: 643.1
# 2. Feature 'eir_270L' - Importance: 639.0
# 3. Feature 'tax_name_last' - Importance: 632.6
# 4. Feature 'tax_name_first' - Importance: 624.9
# 5. Feature 'tax_amount_max' - Importance: 533.8
# 6. Feature 'maxdpdinstldate_3546855D' - Importance: 474.2
# 7. Feature 'employedfrom_700D_max' - Importance: 447.1
# 8. Feature 'annuity_780A' - Importance: 433.6
# 9. Feature 'pctinstlsallpaidlate1d_3546856L' - Importance: 431.3
# 10. Feature 'pmtnum_254L' - Importance: 402.5
# 11. Feature 'sex_738L_first_M' - Importance: 396.5
# 12. Feature 'cntpmts24_3658933L' - Importance: 387.8
# 13. Feature 'birth_259D_max' - Importance: 382.8
# 14. Feature 'firstclxcampaign_1125D' - Importance: 351.8
# 15. Feature 'totaldebt_9A' - Importance: 349.0
# 16. Feature 'pctinstlsallpaidearl3d_427L' - Importance: 328.8
# 17. Feature 'lastrejectdate_50D' - Importance: 324.3
# 18. Feature 'lastrejectcredamount_222A' - Importance: 321.8
# 19. Feature 'language1_981M_first_P209_127_106' - Importance: 319.9
# 20. Feature 'dtlastpmt_581D_last' - Importance: 307.7
# 21. Feature 'date_decision' - Importance: 304.5
# 22. Feature 'maxannuity_159A' - Importance: 288.9
# 23. Feature 'education_1103M_a55475b1' - Importance: 286.5
# 24. Feature 'tax_dateD_max' - Importance: 285.3
# 25. Feature 'district_544M_n' - Importance: 277.2
# 26. Feature 'education_1138M_first_P97_36_170' - Importance: 275.4
# 27. Feature 'maxinstallast24m_3658928A' - Importance: 273.9
# 28. Feature 'days120_123L' - Importance: 272.9
# 29. Feature 'tax_dateD_first' - Importance: 272.0
# 30. Feature 'dtlastpmtallstes_3545839D_last' - Importance: 265.8
# 31. Feature 'byoccupationinc_3656910L_max' - Importance: 265.2
# 32. Feature 'byoccupationinc_3656910L_median' - Importance: 257.8
# 33. Feature 'responsedate_4527233D' - Importance: 257.8
# 34. Feature 'dtlastpmtallstes_3545839D_max' - Importance: 253.4
# 35. Feature 'maxdpdinstlnum_3546846P' - Importance: 252.2
# 36. Feature 'tax_name_count' - Importance: 250.3
# 37. Feature 'tax_name_n' - Importance: 246.6
# 38. Feature 'responsedate_1012D' - Importance: 241.3
# 39. Feature 'avginstallast24m_3658937A' - Importance: 239.7
# 40. Feature 'lastapprcredamount_781A' - Importance: 234.7
# 41. Feature 'incometype_1044T_first_SALARIED_GOVT' - Importance: 234.7
# 42. Feature 'refreshdate_3813885D_last' - Importance: 231.3
# 43. Feature 'weekday_decision' - Importance: 226.7
# 44. Feature 'requesttype_4525192L_nan' - Importance: 226.6
# 45. Feature 'refreshdate_3813885D_median' - Importance: 222.9
# 46. Feature 'credtype_322L_COL' - Importance: 217.2
# 47. Feature 'lastapprdate_640D' - Importance: 216.5
# 48. Feature 'maxlnamtstart6m_4525199A' - Importance: 212.0
# 49. Feature 'isbidproduct_1095L' - Importance: 210.4
# 50. Feature 'childnum_21L_max' - Importance: 208.8
# 51. Feature 'maininc_215A' - Importance: 207.3
# 52. Feature 'totalsettled_863A' - Importance: 203.5
# 53. Feature 'credamount_590A_first' - Importance: 202.9
# 54. Feature 'avgmaxdpdlast9m_3716943P' - Importance: 202.7
# 55. Feature 'numinstpaidlastcontr_4325080L' - Importance: 201.3
# 56. Feature 'annuity_853A_max' - Importance: 199.2
# 57. Feature 'conts_type_509L_last_PRIMARY_MOBILE' - Importance: 198.5
# 58. Feature 'incometype_1044T_first_PRIVATE_SECTOR_EMPLOYEE' - Importance: 194.9
# 59. Feature 'education_1138M_first_a55475b1' - Importance: 194.8
# 60. Feature 'education_927M_first_P97_36_170' - Importance: 194.2
# 61. Feature 'lastapplicationdate_877D' - Importance: 192.5
# 62. Feature 'approvaldate_319D_last' - Importance: 191.3
# 63. Feature 'daysoverduetolerancedd_3976961L' - Importance: 189.2
# 64. Feature 'pmtnum_8L_last' - Importance: 188.4
# 65. Feature 'annuity_853A_median' - Importance: 188.2
# 66. Feature 'thirdquarter_1082L' - Importance: 188.1
# 67. Feature 'pmtnum_8L_max' - Importance: 188.0
# 68. Feature 'secondquarter_766L' - Importance: 186.9
# 69. Feature 'days30_165L' - Importance: 184.6
# 70. Feature 'annuity_853A_first' - Importance: 182.6
# 71. Feature 'creationdate_885D_last' - Importance: 179.4
# 72. Feature 'maritalst_385M_a55475b1' - Importance: 177.0
# 73. Feature 'sex_738L_last_M' - Importance: 176.6
# 74. Feature 'status_219L_last_D' - Importance: 174.3
# 75. Feature 'pmtnum_8L_median' - Importance: 173.2
# 76. Feature 'lastrejectreasonclient_4145040M_a55475b1' - Importance: 172.1
# 77. Feature 'credamount_590A_median' - Importance: 171.9
# 78. Feature 'disbursementtype_67L_SBA' - Importance: 170.9
# 79. Feature 'cntincpaycont9m_3716944L' - Importance: 170.1
# 80. Feature 'credamount_590A_max' - Importance: 167.7
# 81. Feature 'numinstlswithdpd10_728L' - Importance: 167.6
# 82. Feature 'education_1138M_last_a55475b1' - Importance: 166.9
# 83. Feature 'month_decision' - Importance: 166.6
# 84. Feature 'status_219L_first_K' - Importance: 159.4
# 85. Feature 'creationdate_885D_max' - Importance: 158.6
# 86. Feature 'fourthquarter_440L' - Importance: 158.1
# 87. Feature 'numinstlallpaidearly3d_817L' - Importance: 158.0
# 88. Feature 'day_decision' - Importance: 154.2
# 89. Feature 'cancelreason_3545846M_count' - Importance: 154.1
# 90. Feature 'incometype_1044T_first_RETIRED_PENSIONER' - Importance: 150.1
# 91. Feature 'status_219L_first_D' - Importance: 149.8
# 92. Feature 'mobilephncnt_593L' - Importance: 149.0
# 93. Feature 'firstquarter_103L' - Importance: 147.1
# 94. Feature 'childnum_21L_median' - Importance: 146.6
# 95. Feature 'credtype_587L_first_COL' - Importance: 146.1
# 96. Feature 'education_1138M_last_P97_36_170' - Importance: 145.5
# 97. Feature 'lastapprcommoditycat_1041M_a55475b1' - Importance: 145.2
# 98. Feature 'mainoccupationinc_437A_median' - Importance: 143.2
# 99. Feature 'numinstpaidlate1d_3546852L' - Importance: 142.7
# 100. Feature 'familystate_447L_first_nan' - Importance: 142.6
# 101. Feature 'inittransactioncode_279L_last_POS' - Importance: 142.0
# 102. Feature 'inittransactioncode_186L_POS' - Importance: 140.6
# 103. Feature 'inittransactioncode_279L_first_POS' - Importance: 139.9
# 104. Feature 'language1_981M_last_P209_127_106' - Importance: 139.5
# 105. Feature 'mainoccupationinc_437A_last' - Importance: 137.6
# 106. Feature 'credtype_322L_REL' - Importance: 136.7
# 107. Feature 'lastcancelreason_561M_a55475b1' - Importance: 136.5
# 108. Feature 'lastst_736L_D' - Importance: 132.0
# 109. Feature 'downpmt_134A_max' - Importance: 129.7
# 110. Feature 'district_544M_count' - Importance: 128.9
# 111. Feature 'credtype_587L_last_COL' - Importance: 127.3
# 112. Feature 'mainoccupationinc_437A_max' - Importance: 126.0
# 113. Feature 'maxdpdtolerance_374P' - Importance: 121.8
# 114. Feature 'lastrejectreason_759M_a55475b1' - Importance: 121.4
# 115. Feature 'familystate_726L_first_SINGLE' - Importance: 121.0
# 116. Feature 'mainoccupationinc_384A_max' - Importance: 120.4
# 117. Feature 'postype_4733339M_first_a55475b1' - Importance: 120.1
# 118. Feature 'mainoccupationinc_437A_first' - Importance: 119.9
# 119. Feature 'lastrejectreason_759M_P99_56_166' - Importance: 119.7
# 120. Feature 'pmtnum_8L_first' - Importance: 119.6
# 121. Feature 'lastapprcommoditycat_1041M_P159_130_59' - Importance: 119.4
# 122. Feature 'familystate_447L_first_SINGLE' - Importance: 118.0
# 123. Feature 'rejectreason_755M_last_a55475b1' - Importance: 115.0
# 124. Feature 'rejectreason_755M_n' - Importance: 114.3
# 125. Feature 'maxdpdlast12m_727P' - Importance: 113.8
# 126. Feature 'status_219L_last_K' - Importance: 113.6
# 127. Feature 'empl_employedtotal_800L_count' - Importance: 113.2
# 128. Feature 'currdebt_94A_first' - Importance: 113.0
# 129. Feature 'language1_981M_last_a55475b1' - Importance: 110.2
# 130. Feature 'posfstqpd30lastmonth_3976962P' - Importance: 108.0
# 131. Feature 'incometype_1044T_last_SALARIED_GOVT' - Importance: 106.0
# 132. Feature 'rejectreason_755M_last_P99_56_166' - Importance: 105.3
# 133. Feature 'lastrejectcommoditycat_161M_a55475b1' - Importance: 105.1
# 134. Feature 'description_5085714M_a55475b1' - Importance: 104.9
# 135. Feature 'lastst_736L_K' - Importance: 104.7
# 136. Feature 'credtype_587L_first_REL' - Importance: 104.7
# 137. Feature 'currdebt_94A_median' - Importance: 103.5
# 138. Feature 'education_927M_first_a55475b1' - Importance: 103.5
# 139. Feature 'amount_416A_max' - Importance: 103.4
# 140. Feature 'lastapprcommoditycat_1041M_nan' - Importance: 103.2
# 141. Feature 'education_1103M_nan' - Importance: 98.3
# 142. Feature 'incometype_1044T_last_PRIVATE_SECTOR_EMPLOYEE' - Importance: 97.2
# 143. Feature 'openingdate_313D_max' - Importance: 97.0
# 144. Feature 'inittransactioncode_279L_n' - Importance: 97.0
# 145. Feature 'posfpd30lastmonth_3976960P' - Importance: 96.7
# 146. Feature 'role_1084L_last_PE' - Importance: 95.9
# 147. Feature 'rejectreasonclient_4145042M_last_a55475b1' - Importance: 95.8
# 148. Feature 'familystate_726L_last_SINGLE' - Importance: 95.3
# 149. Feature 'maritalst_385M_a7fcb6e5' - Importance: 95.1
# 150. Feature 'lastrejectcommoditycat_161M_nan' - Importance: 95.0
# 151. Feature 'cancelreason_3545846M_last_a55475b1' - Importance: 94.6
# 152. Feature 'empl_industry_691L_count' - Importance: 94.4
# 153. Feature 'conts_type_509L_last_HOME_PHONE' - Importance: 94.1
# 154. Feature 'conts_type_509L_n' - Importance: 89.0
# 155. Feature 'pmts_month_158T_first' - Importance: 88.1
# 156. Feature 'currdebtcredtyperange_828A' - Importance: 85.1
# 157. Feature 'familystate_726L_n' - Importance: 84.6
# 158. Feature 'education_1103M_717ddd49' - Importance: 84.3
# 159. Feature 'homephncnt_628L' - Importance: 84.3
# 160. Feature 'credacc_credlmt_575A_max' - Importance: 83.3
# 161. Feature 'type_25L_last_PRIMARY_MOBILE' - Importance: 81.7
# 162. Feature 'maritalst_385M_nan' - Importance: 81.7
# 163. Feature 'annuitynextmonth_57A' - Importance: 81.7
# 164. Feature 'role_1084L_first_EM' - Importance: 79.6
# 165. Feature 'clientscnt_533L' - Importance: 78.7
# 166. Feature 'posfpd10lastmonth_333P' - Importance: 78.0
# 167. Feature 'safeguarantyflag_411L_count' - Importance: 77.5
# 168. Feature 'conts_type_509L_first_PRIMARY_MOBILE' - Importance: 76.3
# 169. Feature 'persontype_1072L_median' - Importance: 76.1
# 170. Feature 'downpmt_116A' - Importance: 75.1
# 171. Feature 'status_219L_n' - Importance: 74.3
# 172. Feature 'maxdpdlast3m_392P' - Importance: 72.9
# 173. Feature 'requesttype_4525192L_PENSION_6' - Importance: 72.6
# 174. Feature 'incometype_1044T_last_RETIRED_PENSIONER' - Importance: 71.8
# 175. Feature 'numactivecredschannel_414L' - Importance: 71.7
# 176. Feature 'pmts_month_158T_last' - Importance: 71.4
# 177. Feature 'applicationscnt_867L' - Importance: 69.6
# 178. Feature 'numinstpaidearly5d_1087L' - Importance: 67.8
# 179. Feature 'familystate_726L_last_WIDOWED' - Importance: 67.6
# 180. Feature 'downpmt_134A_first' - Importance: 67.4
# 181. Feature 'lastrejectreason_759M_nan' - Importance: 66.6
# 182. Feature 'credtype_587L_n' - Importance: 66.0
# 183. Feature 'cancelreason_3545846M_n' - Importance: 65.5
# 184. Feature 'familystate_447L_last_nan' - Importance: 64.5
# 185. Feature 'relationshiptoclient_415T_count' - Importance: 63.6
# 186. Feature 'postype_4733339M_last_P46_145_78' - Importance: 63.3
# 187. Feature 'status_219L_last_T' - Importance: 63.1
# 188. Feature 'familystate_726L_first_WIDOWED' - Importance: 62.2
# 189. Feature 'num_group2_applprev2_max' - Importance: 61.6
# 190. Feature 'rejectreason_755M_first_a55475b1' - Importance: 60.2
# 191. Feature 'isbidproduct_390L_n' - Importance: 59.5
# 192. Feature 'sellerplacecnt_915L' - Importance: 59.0
# 193. Feature 'num_group1_person2_max' - Importance: 59.0
# 194. Feature 'postype_4733339M_last_a55475b1' - Importance: 58.1
# 195. Feature 'lastcancelreason_561M_nan' - Importance: 57.4
# 196. Feature 'clientscnt_1022L' - Importance: 56.7
# 197. Feature 'cancelreason_3545846M_first_a55475b1' - Importance: 56.7
# 198. Feature 'isbidproduct_390L_last_True' - Importance: 56.7
# 199. Feature 'conts_role_79M_count' - Importance: 55.7
# 200. Feature 'credacc_credlmt_575A_median' - Importance: 55.2
# 201. Feature 'education_1138M_n' - Importance: 54.9
# 202. Feature 'incometype_1044T_count' - Importance: 54.9
# 203. Feature 'num_group1_debitcard_max' - Importance: 54.5
# 204. Feature 'postype_4733339M_n' - Importance: 54.0
# 205. Feature 'conts_type_509L_last_PHONE' - Importance: 53.8
# 206. Feature 'clientscnt12m_3712952L' - Importance: 52.4
# 207. Feature 'contractenddate_991D_max' - Importance: 52.4
# 208. Feature 'postype_4733339M_first_nan' - Importance: 52.0
# 209. Feature 'lastst_736L_T' - Importance: 50.3
# 210. Feature 'conts_type_509L_first_nan' - Importance: 50.2
# 211. Feature 'clientscnt_1071L' - Importance: 49.8
# 212. Feature 'familystate_447L_last_SINGLE' - Importance: 49.7
# 213. Feature 'rejectreasonclient_4145042M_first_a55475b1' - Importance: 48.2
# 214. Feature 'numactiverelcontr_750L' - Importance: 46.8
# 215. Feature 'num_group2_bureaub22_max' - Importance: 46.2
# 216. Feature 'postype_4733339M_last_nan' - Importance: 45.6
# 217. Feature 'numactivecreds_622L' - Importance: 44.9
# 218. Feature 'conts_role_79M_n' - Importance: 42.7
# 219. Feature 'numrejects9m_859L' - Importance: 42.6
# 220. Feature 'status_219L_first_T' - Importance: 42.1
# 221. Feature 'downpmt_134A_median' - Importance: 42.1
# 222. Feature 'postype_4733339M_first_P46_145_78' - Importance: 40.8
# 223. Feature 'clientscnt_946L' - Importance: 40.8
# 224. Feature 'cacccardblochreas_147M_n' - Importance: 38.3
# 225. Feature 'credacc_credlmt_575A_last' - Importance: 37.8
# 226. Feature 'empls_economicalst_849M_n' - Importance: 37.5
# 227. Feature 'maxdebtpduevalodued_3940955A_max' - Importance: 36.4
# 228. Feature 'incometype_1044T_first_nan' - Importance: 36.1
# 229. Feature 'contractdate_551D_max' - Importance: 35.9
# 230. Feature 'numinstls_657L' - Importance: 35.7
# 231. Feature 'downpmt_134A_last' - Importance: 35.6
# 232. Feature 'clientscnt_100L' - Importance: 34.1
# 233. Feature 'clientscnt3m_3712950L' - Importance: 33.7
# 234. Feature 'dpdmax_851P_median' - Importance: 33.4
# 235. Feature 'rejectreason_755M_first_P99_56_166' - Importance: 32.8
# 236. Feature 'clientscnt_304L' - Importance: 32.5
# 237. Feature 'clientscnt_1130L' - Importance: 31.6
# 238. Feature 'familystate_726L_first_nan' - Importance: 30.9
# 239. Feature 'dpd_550P_max' - Importance: 29.6
# 240. Feature 'credtype_587L_last_REL' - Importance: 29.5
# 241. Feature 'isdebitcard_527L_count' - Importance: 29.1
# 242. Feature 'education_927M_count' - Importance: 27.1
# 243. Feature 'numnotactivated_1143L' - Importance: 27.1
# 244. Feature 'language1_981M_first_nan' - Importance: 26.6
# 245. Feature 'lastrejectreasonclient_4145040M_nan' - Importance: 25.9
# 246. Feature 'role_1084L_last_nan' - Importance: 25.7
# 247. Feature 'education_927M_last_nan' - Importance: 25.0
# 248. Feature 'maxdebtpduevalodued_3940955A_median' - Importance: 23.3
# 249. Feature 'description_5085714M_nan' - Importance: 21.3
# 250. Feature 'totalamount_881A_max' - Importance: 20.8
# 251. Feature 'clientscnt_157L' - Importance: 20.2
# 252. Feature 'interestrateyearly_538L_max' - Importance: 19.6
# 253. Feature 'credlmt_228A_max' - Importance: 18.5
# 254. Feature 'purposeofcred_722M_first_96a8fdfe' - Importance: 17.8
# 255. Feature 'actualdpdtolerance_344P' - Importance: 17.7
# 256. Feature 'numpmtchanneldd_318L' - Importance: 17.2
# 257. Feature 'disbursementtype_67L_nan' - Importance: 17.1
# 258. Feature 'incometype_1044T_last_nan' - Importance: 16.0
# 259. Feature 'inittransactioncode_186L_nan' - Importance: 15.3
# 260. Feature 'applicationscnt_1086L' - Importance: 15.2
# 261. Feature 'lastst_736L_nan' - Importance: 14.5
# 262. Feature 'clientscnt_887L' - Importance: 14.5
# 263. Feature 'familystate_726L_last_nan' - Importance: 14.4
# 264. Feature 'contractmaturitydate_151D_last' - Importance: 13.9
# 265. Feature 'residualamount_127A_max' - Importance: 13.2
# 266. Feature 'instlamount_892A_max' - Importance: 13.1
# 267. Feature 'pmtnumpending_403L_max' - Importance: 12.5
# 268. Feature 'clientscnt_493L' - Importance: 10.6
# 269. Feature 'type_25L_first_nan' - Importance: 10.5
# 270. Feature 'applicationscnt_464L' - Importance: 10.1
# 271. Feature 'subjectrole_326M_last_ab3c25cf' - Importance: 10.0
# 272. Feature 'rejectreason_755M_first_nan' - Importance: 10.0
# 273. Feature 'installmentamount_833A_max' - Importance: 9.9
# 274. Feature 'isbidproduct_390L_first_nan' - Importance: 9.7
# 275. Feature 'classificationofcontr_1114M_first_ea6782cc' - Importance: 9.5
# 276. Feature 'subjectrole_43M_first_ab3c25cf' - Importance: 9.5
# 277. Feature 'credlmt_1052A_max' - Importance: 8.7
# 278. Feature 'credor_3940957M_first_b619fa46' - Importance: 8.5
# 279. Feature 'contractmaturitydate_151D_max' - Importance: 8.1
# 280. Feature 'lastupdate_260D_max' - Importance: 8.1
# 281. Feature 'credquantity_984L_max' - Importance: 8.0
# 282. Feature 'dpdmaxdatemonth_804T_last' - Importance: 8.0
# 283. Feature 'dpdmaxdatemonth_804T_first' - Importance: 7.2
# 284. Feature 'dpdmaxdatemonth_804T_max' - Importance: 7.2
# 285. Feature 'contractmaturitydate_151D_mean' - Importance: 6.8
# 286. Feature 'classificationofcontr_1114M_n' - Importance: 6.5
# 287. Feature 'periodicityofpmts_997M_n' - Importance: 5.9
# 288. Feature 'pmtmethod_731M_n' - Importance: 5.8
# 289. Feature 'num_group1_bureaub22_count' - Importance: 5.7
# 290. Feature 'classificationofcontr_1114M_count' - Importance: 5.3
# 291. Feature 'subjectrole_43M_n' - Importance: 4.8
# 292. Feature 'applications30d_658L' - Importance: 4.8
# 293. Feature 'pmts_date_1107D_last' - Importance: 4.8
# 294. Feature 'dpdmaxdatemonth_804T_median' - Importance: 4.4
# 295. Feature 'credor_3940957M_last_nan' - Importance: 4.2
# 296. Feature 'cancelreason_3545846M_first_nan' - Importance: 4.2
# 297. Feature 'pmtmethod_731M_first_f6e26148' - Importance: 4.1
# 298. Feature 'rejectreason_755M_last_nan' - Importance: 3.9
# 299. Feature 'contracttype_653M_n' - Importance: 3.7
# 300. Feature 'periodicityofpmts_997M_first_a55475b1' - Importance: 3.6
# 301. Feature 'subjectrole_43M_last_ab3c25cf' - Importance: 3.4
# 302. Feature 'purposeofcred_722M_n' - Importance: 3.4
# 303. Feature 'subjectrole_326M_first_ab3c25cf' - Importance: 3.3
# 304. Feature 'subjectrole_326M_n' - Importance: 3.2
# 305. Feature 'dpd_733P_max' - Importance: 3.0
# 306. Feature 'credor_3940957M_last_b619fa46' - Importance: 3.0
# 307. Feature 'numcontrs3months_479L' - Importance: 2.9
# 308. Feature 'pmtmethod_731M_first_dbcbe8f8' - Importance: 2.5
# 309. Feature 'contractst_516M_n' - Importance: 2.5
# 310. Feature 'installmentamount_644A_max' - Importance: 2.4
# 311. Feature 'dpdmaxdateyear_742T_max' - Importance: 2.4
# 312. Feature 'cancelreason_3545846M_last_nan' - Importance: 2.3
# 313. Feature 'pmts_dpdvalue_108P_last' - Importance: 2.3
# 314. Feature 'periodicityofpmts_997M_last_a55475b1' - Importance: 2.2
# 315. Feature 'contracttype_653M_last_4257cbed' - Importance: 2.2
# 316. Feature 'lastupdate_260D_last' - Importance: 2.1
# 317. Feature 'pmtmethod_731M_last_nan' - Importance: 2.1
# 318. Feature 'credor_3940957M_count' - Importance: 2.0
# 319. Feature 'status_219L_first_nan' - Importance: 1.8
# 320. Feature 'education_1138M_first_nan' - Importance: 1.4
# 321. Feature 'classificationofcontr_1114M_last_nan' - Importance: 1.4
# 322. Feature 'credor_3940957M_first_nan' - Importance: 1.2
# 323. Feature 'contracttype_653M_first_4257cbed' - Importance: 1.1
# 324. Feature 'periodicityofpmts_997M_first_nan' - Importance: 1.0
# 325. Feature 'inittransactioncode_279L_first_nan' - Importance: 0.9
# 326. Feature 'rejectreasonclient_4145042M_first_nan' - Importance: 0.8
# 327. Feature 'periodicityofpmts_997M_last_nan' - Importance: 0.8
# 328. Feature 'rejectreasonclient_4145042M_last_nan' - Importance: 0.7
# 329. Feature 'pmts_dpdvalue_108P_median' - Importance: 0.7
# 330. Feature 'education_1138M_last_nan' - Importance: 0.6
# 331. Feature 'pmts_dpdvalue_108P_first' - Importance: 0.6
# 332. Feature 'contracttype_653M_last_nan' - Importance: 0.5
# 333. Feature 'subjectrole_326M_first_nan' - Importance: 0.5
# 334. Feature 'conts_type_509L_last_nan' - Importance: 0.5
# 335. Feature 'contracttype_653M_first_nan' - Importance: 0.5
# 336. Feature 'inittransactioncode_279L_last_nan' - Importance: 0.4
# 337. Feature 'credtype_587L_first_nan' - Importance: 0.3
# 338. Feature 'classificationofcontr_1114M_first_nan' - Importance: 0.3
# 339. Feature 'purposeofcred_722M_last_nan' - Importance: 0.2
# 340. Feature 'subjectrole_326M_last_nan' - Importance: 0.2
# 341. Feature 'subjectrole_43M_first_nan' - Importance: 0.2
# 342. Feature 'purposeofcred_722M_first_nan' - Importance: 0.2
# 343. Feature 'subjectrole_43M_last_nan' - Importance: 0.1
# 344. Feature 'status_219L_last_nan' - Importance: 0.1
# 345. Feature 'empladdr_district_926M_n' - Importance: 0.0
# 346. Feature 'persontype_1072L_first' - Importance: 0.0
# 347. Feature 'purposeofcred_722M_last_96a8fdfe' - Importance: 0.0
# 348. Feature 'contaddr_smempladdr_334L_count' - Importance: 0.0
# 349. Feature 'personindex_1023L_first' - Importance: 0.0
# 350. Feature 'clientscnt_257L' - Importance: 0.0
# 351. Feature 'pmtmethod_731M_last_f6e26148' - Importance: 0.0
# 352. Feature 'pmtmethod_731M_last_e914c86c' - Importance: 0.0
# 353. Feature 'pmtmethod_731M_first_nan' - Importance: 0.0
# 354. Feature 'pmtmethod_731M_first_e914c86c' - Importance: 0.0
# 355. Feature 'credor_3940957M_last_c5a72b57' - Importance: 0.0
# 356. Feature 'credor_3940957M_first_c5a72b57' - Importance: 0.0
# 357. Feature 'credor_3940957M_first_P33_61_72' - Importance: 0.0
# 358. Feature 'classificationofcontr_1114M_first_01f63ac8' - Importance: 0.0
# 359. Feature 'clientscnt_360L' - Importance: 0.0
# 360. Feature 'isbidproduct_390L_last_nan' - Importance: 0.0
# 361. Feature 'credtype_587L_last_nan' - Importance: 0.0
# 362. Feature 'type_25L_last_nan' - Importance: 0.0
# 363. Feature 'role_1084L_first_nan' - Importance: 0.0
# 364. Feature 'education_927M_first_nan' - Importance: 0.0
# 365. Feature 'credtype_322L_nan' - Importance: 0.0
# Catboost CV AUC scores:  [0.9059423303504427, 0.8986381125907341, 0.9070709831216557, 0.9115769796826827, 0.9094491769415866, 0.910784866008889, 0.9137514305979061, 0.9079599859379531, 0.911871313459279, 0.9088805988150307]
# Maximum Catboost CV AUC score:  0.9137514305979061
# Lightgbm CV AUC scores:  [0.9082110355379599, 0.9013023013726766, 0.9106492018092727, 0.9127152335882798, 0.9103485001580967, 0.9122012698815538, 0.9152324456495173, 0.9091063681533236, 0.9132834235282331, 0.9101626567176009]
# Maximum Lightgbm CV AUC score:  0.9152324456495173

# %%
import joblib
joblib.dump(fitted_models_lgb,'model62-lgb.pkl')
joblib.dump(fitted_models_cat,'model62-cat.pkl')
# Out:
# ['model62-cat.pkl']

# %%
all1.shape

# %%
all1.dtypes
